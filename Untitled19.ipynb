# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga643/Example/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
plt.plot([0, 1, 2, 3], [10, 9, 6, 1])
plt.xlabel('x')
plt.title('Example')
plt.grid()

# %%
df = pd.read_csv('laptops_10.csv', encoding='1251')
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# 1            128  FlashStorage
# 2            256           SSD
# 3            512           SSD
# 4            256           SSD

# %% [markdown]
# ### 1.1 Изучите распределение количества памяти (Memory_Amount) с помощью matplotlib

# %%
plt.figure(figsize=(20, 6))
plt.hist(df['Memory_Amount'], bins=50)
plt.title('Распределение памяти')
plt.xlabel('Объем памятии, GB')
plt.ylabel('Количество')
plt.xticks(range(0, 2100, 32), rotation=45)
plt.grid();

# %% [markdown]
# ### 1.2 Изучите распределение стоимости ноутбуков (Price_euros) с помощью matplotlib

# %%
df['Price_euros'].value_counts()
# Out:
# 1499.0    14
# 1099.0    14
# 1799.0    14
# 899.0     11
# 1199.0    11
#           ..
# 2090.0     1
# 304.0      1
# 759.0      1
# 1858.0     1
# 2699.0     1
# Name: Price_euros, Length: 791, dtype: int64

# %%
df['Price_euros'].max(), df['Price_euros'].min()
# Out:
# (6099.0, 174.0)

# %%
plt.figure(figsize=(20, 6))
plt.hist(df['Price_euros'], bins=100)
plt.title('Распределение стоимости')
plt.xlabel('Прайс')
plt.ylabel('Количество')
#plt.xticks(range(0, 7000))
plt.grid();

# %% [markdown]
# ### 1.3 Изучите распределение веса ноутбуков (Weight) с помощью matplotlib

# %%
df['Weight'].value_counts()
# Out:
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: Weight, Length: 171, dtype: int64

# %%
df['Weight'].max(), df['Weight'].min()
# Out:
# (4.7, 0.69)

# %%
plt.figure(figsize=(20, 10))
plt.hist(df['Weight'], bins=20)
plt.title('Распределение веса')
plt.xlabel('Вес')
plt.ylabel('Количество')
plt.xticks([ i/100 for i in range(0, 501, 25)])
plt.grid();

# %% [markdown]
# ### 2.1 Изучите распределение типов носителя (Memory_Type)

# %%
data = df['Memory_Type'].value_counts()
data
# Out:
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: Memory_Type, dtype: int64

# %%
plt.pie(data.values, labels=data.index, autopct='%.3f%%')
plt.title('Распределение типов носителей');

# %% [markdown]
# ### 2.2 Изучите распределение компаний производителей (Company)

# %%
data1 = df['Company'].value_counts()
data1
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
plt.figure(figsize=(20, 10))
plt.bar(data1.index, data1.values)
plt.xticks(rotation=50)
plt.grid();

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %% [markdown]
# ### 2.3 Изучите распределение операционной системы (OpSys)

# %%
data2 = df['OpSys'].value_counts()
data2
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
plt.figure(figsize=(20, 10))
plt.bar(data2.index, data2.values)
plt.xticks(rotation=50)
plt.grid();

# %% [markdown]
# ### 2.4 Изучите распределение компаний производителей CPU (Cpu_Company)

# %%
data3 = df['Cpu_Company'].value_counts()
data3
# Out:
# Intel      1240
# AMD          62
# Samsung       1
# Name: Cpu_Company, dtype: int64

# %%
plt.pie(data3.values, labels=data3.index, autopct='%.1f%%')
plt.title('Распределение компаний производителей');

# %% [markdown]
# ## Задание 3
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму
# Процессоры от Samsung не изучайте

# %% [markdown]
# ### 3.1 Постройте график в абсолютных величинах

# %%
data = pd.crosstab(df['Company'], df['Cpu_Company'])
data = data.reset_index().drop(columns=['Samsung'])

data
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
plt.figure(figsize=(20, 10))
n_ticks = np.arange(len(data['AMD']))
offset = 0.2
w = 0.4
plt.bar(n_ticks - offset, data['AMD'], width=w)
plt.bar(n_ticks + offset, data['Intel'], width=w)
plt.title('Notebook')
plt.xlabel('Company')
plt.ylabel('Quantity')
plt.legend(['AMD', 'Intel'])
plt.xticks(n_ticks, data['Company']);

# %% [markdown]
# ### 3.2 Постройте график в относительных величинах

# %%
data = pd.crosstab(df['Company'], df['Cpu_Company'], normalize='index').reset_index()
data.drop(columns=['Samsung'], inplace=True)
data
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Samsung  0.000000  0.888889
# 16             Toshiba  0.000000  1.000000
# 17                Vero  0.000000  1.000000
# 18              Xiaomi  0.000000  1.000000

# %%
plt.figure(figsize=(20, 10))
plt.bar(data['Company'], data['AMD'])
plt.bar(data['Company'], data['Intel'], bottom=data['AMD'])
plt.title('Notebook')
plt.xlabel('Company')
plt.ylabel('Quantity')
plt.legend(['AMD', 'Intel'])
plt.xticks(n_ticks, data['Company']);

# %% [markdown]
# ## Задание 4.
# ### 4.1 Изучите взаимосвязь стоимости ноутбука и компании производителя процессора

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(x=df['Price_euros'], y=df['Cpu_Company'])
plt.title('Взаимосвязь стоимости ноутбука и компании производителя процессора')
plt.grid();

# %% [markdown]
# ### 4.2 Изучите взаимосвязь стоимости ноутбука и типа носителя памяти

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(x=df['Price_euros'], y=df['Memory_Type'])
plt.title('Взаимосвязь стоимости ноутбука и и типа носителя памяти');

# %% [markdown]
# ### 4.3 Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(x=df['Price_euros'], y=df['Ram'])
plt.title('Взаимосвязь стоимости ноутбука и кол-ва оперативной памяти')
plt.grid();

# %% [markdown]
# ### 4.4 Изучите взаимосвязь стоимости ноутбука и компании производителя

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(x=df['Price_euros'], y=df['Company'])
plt.title('Взаимосвязь стоимости ноутбука и компании производителя')
plt.grid();

# %% [markdown]
# ## Задание 5*.
# Постройте матрицу корреляций для таблицы

# %%
corr_m = df.corr().round(2)
corr_m[np.abs(corr_m)<0.3] = 0
corr_m
# Out:
# <ipython-input-142-a98b64da8b8c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_m = df.corr().round(2)
#                Inches  Weight  Price_euros  Memory_Amount
# Inches           1.00    0.83          0.0            0.0
# Weight           0.83    1.00          0.0            0.0
# Price_euros      0.00    0.00          1.0            0.0
# Memory_Amount    0.00    0.00          0.0            1.0

# %%
plt.figure(figsize=(8,4))
sns.set(font_scale=1.4)
sns.heatmap(corr_m, annot=True, linewidths=.5, cmap='coolwarm')
# Out:
# <Axes: >
