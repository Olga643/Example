# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga643/Example/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Проанализируйте результаты эксперимента и напишите свои рекомендации менеджеру.
#
# Mobile Games AB Testing with Cookie Cats

# %%
from scipy import stats
import numpy as np
from statsmodels.stats.power import TTestIndPower
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# 1 этап. Проверка данных

# %%
data = pd.read_csv('/content/результаты А_B - cookie_cats 2.csv')

# %%
data.head()
# Out:
#    userid  version  sum_gamerounds  retention_1  retention_7
# 0     116  gate_30               3            0            0
# 1     337  gate_30              38            1            0
# 2     377  gate_40             165            1            0
# 3     483  gate_40               1            0            0
# 4     488  gate_40             179            1            1

# %%
data.shape
# Out:
# (90189, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90189 entries, 0 to 90188
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userid          90189 non-null  int64
#  1   version         90189 non-null  object
#  2   sum_gamerounds  90189 non-null  int64
#  3   retention_1     90189 non-null  int64
#  4   retention_7     90189 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 3.4+ MB

# %%
data.describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  9.018900e+04    90189.000000  90189.000000  90189.000000
# mean   4.998412e+06       51.872457      0.445210      0.186065
# std    2.883286e+06      195.050858      0.496992      0.389161
# min    1.160000e+02        0.000000      0.000000      0.000000
# 25%    2.512230e+06        5.000000      0.000000      0.000000
# 50%    4.995815e+06       16.000000      0.000000      0.000000
# 75%    7.496452e+06       51.000000      1.000000      0.000000
# max    9.999861e+06    49854.000000      1.000000      1.000000

# %%
data["userid"].nunique()
# Out:
# 90189

# %%
data.groupby("version")[["userid"]].nunique()
# Out:
#          userid
# version
# gate_30   44700
# gate_40   45489

# %%
44700+45489
# Out:
# 90189

# %%
v = data.\
    groupby('userid', as_index=False).\
    agg({'version': pd.Series.nunique})

# %%
v.head()
# Out:
#    userid  version
# 0     116        1
# 1     337        1
# 2     377        1
# 3     483        1
# 4     488        1

# %%
more_than_one_types = v.query('version > 1')

# %%
data_new = data[~data.userid.isin(more_than_one_types.userid)].sort_values('userid')

# %%
data_new.shape
# Out:
# (90189, 5)

# %%
data[data['version']=='gate_30'].describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  4.470000e+04    44700.000000  44700.000000  44700.000000
# mean   4.987564e+06       52.456264      0.448188      0.190201
# std    2.881026e+06      256.716423      0.497314      0.392464
# min    1.160000e+02        0.000000      0.000000      0.000000
# 25%    2.505469e+06        5.000000      0.000000      0.000000
# 50%    4.983631e+06       17.000000      0.000000      0.000000
# 75%    7.481497e+06       50.000000      1.000000      0.000000
# max    9.999710e+06    49854.000000      1.000000      1.000000

# %%
data[data['version']=='gate_40'].describe()
# Out:
#              userid  sum_gamerounds   retention_1   retention_7
# count  4.548900e+04    45489.000000  45489.000000  45489.000000
# mean   5.009073e+06       51.298776      0.442283      0.182000
# std    2.885496e+06      103.294416      0.496663      0.385849
# min    3.770000e+02        0.000000      0.000000      0.000000
# 25%    2.517171e+06        5.000000      0.000000      0.000000
# 50%    5.007329e+06       16.000000      0.000000      0.000000
# 75%    7.510762e+06       52.000000      1.000000      0.000000
# max    9.999861e+06     2640.000000      1.000000      1.000000

# %%
data[(data['sum_gamerounds']== 0) & (data['version']=='gate_30')]["userid"].count()
# Out:
# 1937

# %%
data[(data['sum_gamerounds']== 0) & (data['version']=='gate_40')]["userid"].count()
# Out:
# 2057

# %% [markdown]
# Тест проведен корректно, пользователи распределены по группам равномерно. Нет повторяющихся пользователей в группах. Первоначально можно сказать, что результаты по удержанию пользователей на 1 и 7 день по тестовой группе gate_40 немного хуже, чем по gate_30

# %%
from scipy.stats import shapiro

# %%
alpha = 0.05

st = shapiro(data.sum_gamerounds)
print('Distribution is {}normal\n'.format( {True:'not ',
False:''}[st[1] < alpha]));
# Out:
# Distribution is not normal

# %%
alpha = 0.05

st = shapiro(data.retention_1)
print('Distribution is {}normal\n'.format( {True:'not ',
False:''}[st[1] < alpha]));
# Out:
# Distribution is not normal

# %%
alpha = 0.05

st = shapiro(data.retention_7)
print('Distribution is {}normal\n'.format( {True:'not ',
False:''}[st[1] < alpha]));
# Out:
# Distribution is not normal

# %%
data.groupby('version')['sum_gamerounds'].describe()
# Out:
#            count       mean         std  min  25%   50%   75%      max
# version
# gate_30  44700.0  52.456264  256.716423  0.0  5.0  17.0  50.0  49854.0
# gate_40  45489.0  51.298776  103.294416  0.0  5.0  16.0  52.0   2640.0

# %%
mw_stats = stats.mannwhitneyu(x=data[data['version'] == 'gate_30']['sum_gamerounds'].values,
                                                  y=data[data['version'] == 'gate_40']['sum_gamerounds'].values)
mw_stats
# Out:
# MannwhitneyuResult(statistic=1024331250.5, pvalue=0.05020880772044255)

# %% [markdown]
# По количеству игровых раундов нет отличия между тестовой и контрольной группой

# %%
control = data.query('version == "gate_30"')

test = data.query('version == "gate_40"')

# %%
data[(data['retention_1']== 1) & (data['version']=='gate_30')]["userid"].count()
# Out:
# 20034

# %%
20034/44700*100
# Out:
# 44.81879194630872

# %%
mw_stats=stats.mannwhitneyu(x=control.retention_1.values, y=test.retention_1.values)
mw_stats
# Out:
# MannwhitneyuResult(statistic=1022682813.0, pvalue=0.07441128639919536)

# %%
data[(data['retention_1']== 1) & (data['version']=='gate_40')]["userid"].count()
# Out:
# 20119

# %%
20119/45489*100
# Out:
# 44.22827496757458

# %%
data[(data['retention_7']== 1) & (data['version']=='gate_30')]["userid"].count()
# Out:
# 8502

# %%
a = 8502/44700*100
a
# Out:
# 19.020134228187917

# %%
data[(data['retention_7']== 1) & (data['version']=='gate_40')]["userid"].count()
# Out:
# 8279

# %%
b = 8279/45489*100
b
# Out:
# 18.200004396667328

# %%
diff = a/b*100 - 100
diff
# Out:
# 4.506206776910275

# %%
mw_stats=stats.mannwhitneyu(x=control.retention_7.values, y=test.retention_7.values)
mw_stats
# Out:
# MannwhitneyuResult(statistic=1025017239.0, pvalue=0.001554344685704005)

# %% [markdown]
# Анализ показал, что нет статистически значимой разницы по количеству игровых раундов и по возвратам 1-го дня. А вот по возвратам 7-го дня есть различия. Но, но данные по группе gate_40 хуже, чем данные по группе gate_30. Процент возвратов на 7 день упал на 4,5% в тестовой группе. Поэтому рекомендую на свигать ворота в игре на 40 уровень.
