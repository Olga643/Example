# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga643/Example/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Auto.csv')
df
# Out:
#                          Client ID                   Domain       City  \
# 0      GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru     Zurich
# 1      GA1.2.1029165320.1581675414  cars.BMW-keyauto-krd.ru     Zurich
# 2      GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru     Zurich
# 3       GA1.2.360702973.1573932024       BMW-keyauto-krd.ru     Zurich
# 4      GA1.2.1394084210.1579796276    Mersedes-krasnodar.ru     Zurich
# ...                            ...                      ...        ...
# 66157   GA1.2.719597775.1578814255       BMW-keyauto-krd.ru  (not set)
# 66158  GA1.2.1787735095.1578381366    Mersedes-krasnodar.ru  (not set)
# 66159  GA1.2.1994191491.1578813741    Mersedes-krasnodar.ru  (not set)
# 66160    GA1.2.83095213.1578206594    Mersedes-krasnodar.ru  (not set)
# 66161  GA1.2.1866392047.1579068850    Mersedes-krasnodar.ru  (not set)
#
#           Region    Browser Device Category                Date  Pageviews  \
# ...

# %%
df.dtypes
# Out:
# Client ID                   object
# Domain                      object
# City                        object
# Region                      object
# Browser                     object
# Device Category             object
# Date                        object
# Pageviews                    int64
# Campaign                    object
# Keyword                     object
# Medium                      object
# Source                      object
#  Avg. Session Duration      object
#  Bounce Rate                object
# Sessions                     int64
# Goal Completion Location    object
# Goal Completions             int64
# Goal Conversion Rate        object
# Goal Value                  object
# Конверсия                    int64
# Source conv.                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Client ID                   0
# Domain                      0
# City                        0
# Region                      0
# Browser                     0
# Device Category             0
# Date                        0
# Pageviews                   0
# Campaign                    0
# Keyword                     0
# Medium                      0
# Source                      0
#  Avg. Session Duration      0
#  Bounce Rate                0
# Sessions                    0
# Goal Completion Location    0
# Goal Completions            0
# Goal Conversion Rate        0
# Goal Value                  0
# Конверсия                   0
# Source conv.                0
# dtype: int64
