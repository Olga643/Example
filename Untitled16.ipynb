# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga643/Example/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Условие 1: 1 задача
# - Скачать файл в уроке
# - Считать данные с помощью pandas
# - Вывести на экран первые 5 строк
# - Посмотреть на описание признаков и на их содержание

# %%
df = pd.read_csv('kc_house_data.csv', encoding='1251')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df = pd.read_csv('kc_house_data.csv', encoding='1251', index_col='id', parse_dates=['date'], dayfirst=False )
df.head()
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900.0         3       1.00         1180      5650
# 6414100192 2014-12-09  538000.0         3       2.25         2570      7242
# 5631500400 2015-02-25  180000.0         2       1.00          770     10000
# 2487200875 2014-12-09  604000.0         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.0         3       2.00         1680      8080
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0           0     0          3      7        1180
# 6414100192     2.0           0     0          3      7        2170
# 5631500400     1.0           0     0          3      6         770
# 2487200875     1.0           0     0          5      7        1050
# 1954400510     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# ...

# %%
df['date'].dt.month_name()
# Out:
# id
# 7129300520     October
# 6414100192    December
# 5631500400    February
# 2487200875    December
# 1954400510    February
#                 ...
# 263000018          May
# 6600060120    February
# 1523300141        June
# 291310100      January
# 1523300157     October
# Name: date, Length: 21613, dtype: object

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# - id - Уникальный ID для каждого дома
# - date - Дата продажи дома
# - price - Стоимость продажи дома
# - bedrooms - Кол-во спален
# - bathrooms - Кол-во ванных комнат (0.5 - туалет без душа)
# - sqft_living - Кв. метры жилые
# - sqft_lot - Кв. метры общие
# - floors - Кол-во этажей
# - waterfront - Есть набержная или нет
# - view - Значение от 0 до 4 насколько хороший вид
# - condition - Значение от 1 до 5 насколько хорошее состояние
# - grade - Значение от 1 до 13, где 1-3 плохая конструкция здания и дизайн, 7 - средний уровень конструкции и дизайна, 11-13 - высокое качество конструкции и дизайна
# - sqft_above - Кв. метры дома, которые находятся выше земли
# - sqft_basement - Кв. метры дома, которые находятся ниже земли
# - yr_built - Год постройки дома
# - yr_renovated - Год ремонта дома
# - zipcode - Индекс
# - lat - Широта
# - long - Долгота
# - sqft_living15 - Кв. метры жилой площади у 15 соседей
# - sqft_lot15 - Кв. метры общей площади у 15 соседей

# %% [markdown]
# ## Условие 2: 2 задача
# Проведите первичный анализ данных
# - Изучите типы данных
# - Найдите количество пропущенных ячеек в данных
# - Посчитайте основные статистики по всем признакам и поизучайте их
# - Пишите выводы

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df['price'].mean()
# Out:
# 540088.1417665294

# %%
df.describe(include=['object'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# Достаточно сложно сделать выводы по основным статистикам. Из того, что видно на первый взгляд: можно определить средние, медианные и минимальные значения стоимости дома, количество спален, ванных комнат и площади домов.

# %% [markdown]
# ## Условие 3: 3 задача
# Ответьте на несколько вопросов
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df['price'].min(),df['price'].max()
# Out:
# (75000.0, 7700000.0)

# %%
df.sort_values('price')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000    75000.0         1       0.00
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1149           670     43377     1.0           0     0  ...      3
# ...

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
liv_sq =round(df['sqft_living'].mean(), 2)
liv_sq
# Out:
# 2079.9

# %%
total_sq =round(df['sqft_lot'].mean(), 2)
total_sq
# Out:
# 15106.97

# %%
part_sq = liv_sq / total_sq*100
part_sq
# Out:
# 13.767817106938057

# %% [markdown]
# В среднем жилая площадь занимает 13% от общей площади дома

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ### 3.4 Насколько хорошие состояния у домов в данных?

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
df['condition'].mean()
# Out:
# 3.4094295100171195

# %% [markdown]
# В среднем состояние домов выше среднего

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %% [markdown]
# *Не очень поняла задание, поэтому нашла самый старый и самый новый дом. И вторым вариантом выбрала год постройки первого и последнего дома по таблице*

# %%
df['yr_built'].min(),df['yr_built'].max()
# Out:
# (1900, 2015)

# %%
df.sort_values('yr_built')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 4697   9126101645  20140610T000000  558000.0         4       2.00
# 2961   1947300115  20140619T000000  464000.0         3       1.00
# 12369  9138100350  20150218T000000  685000.0         4       2.00
# 15016  1703400585  20141215T000000  325000.0         3       2.00
# 5236    844000425  20141223T000000  199999.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 21270  1773100541  20150417T000000  389950.0         3       2.25
# 17098  9126100346  20140617T000000  350000.0         3       2.00
# 7526   9520900210  20141231T000000  614285.0         5       2.75
# 20086  2768100512  20150422T000000  659000.0         2       2.50
# 14489  2770601530  20140826T000000  500000.0         2       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4697          2180      3870     1.0           0     0  ...      7
# ...

# %%
df.loc[0]['yr_built']
# Out:
# 1955

# %%
df.loc[21612]['yr_built']
# Out:
# 2008

# %% [markdown]
# ## Условие 4: 4 задача
# Ответьте на несколько вопросов
#
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df[df['bedrooms'] == 2]['price'].mean()
# Out:
# 401372.681884058

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df['price'] > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?

# %%
df[df['yr_renovated'] != 0].shape[0]
# Out:
# 914

# %%
df[df['yr_renovated'] != 0]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 35     9547205180  20140613T000000   696000.0         3       2.50
# 95     1483300570  20140908T000000   905000.0         4       2.50
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 115    3626039325  20141121T000000   740500.0         3       3.50
# ...           ...              ...        ...       ...        ...
# 19622  7351200295  20150114T000000  1150000.0         3       1.75
# 20057   126039256  20140904T000000   434900.0         3       2.00
# 20444  4305600360  20150225T000000   500012.0         4       2.50
# 20447  3319500628  20150212T000000   356999.0         3       1.50
# 20962  1278000210  20150311T000000   110000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
best_house = df[df['grade'] > 10]['price'].mean()
best_house
# Out:
# 1678635.1175298805

# %%
worst_house = df[df['grade'] < 4]['price'].mean()
worst_house
# Out:
# 189750.0

# %%
diff = round(best_house - worst_house, 2)
diff
# Out:
# 1488885.12

# %% [markdown]
# *В среднем стоимость домов с оценкой больше 10 выше в 9 раз*

# %% [markdown]
# ## Условие 5: 5 задача
# Ответьте на несколько вопросов
# ### 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[(df['waterfront'] == 1) & (df['bathrooms'] >= 3) & (df['sqft_basement'] > 0)].shape[0]
# Out:
# 41

# %% [markdown]
# Для клиента усть 41 предложение, отвечающее его условиям

# %% [markdown]
# ### 5.2 Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
client1 = df[(df['yr_built'] >= 1980) & (df['condition'] > 3) & ((df['view'] > 2) | (df['waterfront'] == 1))]
client1['price'].min(), client1['price'].max()
# Out:
# (420000.0, 5300000.0)

# %% [markdown]
# ### 5.3 Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df[(df['sqft_basement'] == 0) & (df['floors'] == 2) & (df['price'] < 150000)]['condition'].mean().round(2)
# Out:
# 2.83
